# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishjhavats/Colab_demo/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# Image Processing Functions
def resize_image(image, width=None, height=None):

  import
    if width and height:

        return cv2.resize(image, (width, height))
    elif width:
        ratio = width / image.shape[1]
        return cv2.resize(image, (width, int(image.shape[0] * ratio)))
    elif height:
        ratio = height / image.shape[0]
        return cv2.resize(image, (int(image.shape[1] * ratio), height))
    else:
        return image

def apply_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

def apply_blur(image, kernel_size=(5,5)):
    return cv2.GaussianBlur(image, kernel_size, 0)

def detect_edges(image, threshold1=100, threshold2=200):
    return cv2.Canny(image, threshold1, threshold2)

    return cv2.Canny(image, threshold1, threshold2)

# Face Detection Function

def detect_faces(image):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)
    return image

# Video Processing Function
def process_video(input_path, output_path, process_func):
    cap = cv2.VideoCapture(input_path)

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Apply processing function
        processed_frame = process_func(frame)

        # Write the frame
        out.write(processed_frame)

    cap.release()
    out.release()

# Main execution
def main():
    # Upload an image
    uploaded = files.upload()
    filename = next(iter(uploaded))

    # Read the image
    image = cv2.imread(filename)

    # Apply image processing
    resized_image = resize_image(image, width=300)
    gray_image = apply_grayscale(resized_image)
    blurred_image = apply_blur(resized_image)
    edge_image = detect_edges(resized_image)
    face_detected_image = detect_faces(resized_image)

    # Display results
    cv2_imshow(resized_image)
    cv2_imshow(gray_image)
    cv2_imshow(blurred_image)
    cv2_imshow(edge_image)
    cv2_imshow(face_detected_image)

    # Video processing example (uncomment to use)
    # Note: You'll need to upload a video file to Colab first
    # process_video('input_video.mp4', 'output_video.mp4', detect_edges)
    # files.download('output_video.mp4')

if __name__ == "__main__":
    main()
# Out:
#      <input type="file" id="files-e664486a-b068-49a8-b77c-71b7c2597260" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e664486a-b068-49a8-b77c-71b7c2597260">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from deepface import DeepFace

# Analyze a single image
img_path = 'path/to/your/image.jpg'  # Replace with your image path
obj = DeepFace.analyze(img_path=img_path, actions=['age', 'gender'], enforce_detection=False)

print("Age:", obj[0]['age'])
print("Gender:", obj[0]['dominant_gender'])

# Analyze multiple images in a directory
img_dir = 'path/to/your/image/directory'  # Replace with your directory path
dfs = DeepFace.analyze(img_path=img_dir, actions=['age', 'gender'], enforce_detection=False)

for df in dfs:
    print("Age:", df['age'])
    print("Gender:", df['dominant_gender'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-761bb86d883f> in <cell line: 1>()
# ----> 1 from deepface import DeepFace
#       2
#       3 # Analyze a single image
#       4 img_path = 'path/to/your/image.jpg'  # Replace with your image path
#       5 obj = DeepFace.analyze(img_path=img_path, actions=['age', 'gender'], enforce_detection=False)
#
# ModuleNotFoundError: No module named 'deepface'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install deepface

# %%
from deepface import DeepFace

# Analyze a single image
img_path = 'path/to/your/image.jpg'  # Replace with your image path
obj = DeepFace.analyze(img_path=img_path, actions=['age', 'gender'], enforce_detection=False)

print("Age:", obj[0]['age'])
print("Gender:", obj[0]['dominant_gender'])

# Analyze multiple images in a directory
img_dir = 'path/to/your/image/directory'  # Replace with your directory path
dfs = DeepFace.analyze(img_path=img_dir, actions=['age', 'gender'], enforce_detection=False)

for df in dfs:
    print("Age:", df['age'])
    print("Gender:", df['dominant_gender'])
# Out:
# 24-08-10 13:41:16 - Directory /root/.deepface created
# 24-08-10 13:41:16 - Directory /root/.deepface/weights created
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-761bb86d883f> in <cell line: 5>()
#       3 # Analyze a single image
#       4 img_path = 'path/to/your/image.jpg'  # Replace with your image path
# ----> 5 obj = DeepFace.analyze(img_path=img_path, actions=['age', 'gender'], enforce_detection=False)
#       6
#       7 print("Age:", obj[0]['age'])
#
# /usr/local/lib/python3.10/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     245             - 'white': Confidence score for White ethnicity.
#     246     """
# --> 247     return demography.analyze(
#     248         img_path=img_path,
#     249         actions=actions,
#
# ...

# %%
from deepface import DeepFace

# Analyze a single image
img_path = 'actual/path/to/your/image.jpg'  # Replace with the actual path to your image file
obj = DeepFace.analyze(img_path=img_path, actions=['age', 'gender'], enforce_detection=False)

print("Age:", obj[0]['age'])
print("Gender:", obj[0]['dominant_gender'])

# Analyze multiple images in a directory
img_dir = 'actual/path/to/your/image/directory'  # Replace with the actual path to your image directory
dfs = DeepFace.analyze(img_path=img_dir, actions=['age', 'gender'], enforce_detection=False)

for df in dfs:
    print("Age:", df['age'])
    print("Gender:", df['dominant_gender'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-3b04ad962048> in <cell line: 5>()
#       3 # Analyze a single image
#       4 img_path = 'actual/path/to/your/image.jpg'  # Replace with the actual path to your image file
# ----> 5 obj = DeepFace.analyze(img_path=img_path, actions=['age', 'gender'], enforce_detection=False)
#       6
#       7 print("Age:", obj[0]['age'])
#
# /usr/local/lib/python3.10/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     245             - 'white': Confidence score for White ethnicity.
#     246     """
# --> 247     return demography.analyze(
#     248         img_path=img_path,
#     249         actions=actions,
#
# ...

# %%
# !pip install deepface opencv-python

import cv2
from deepface import DeepFace

# Initialize video capture
cap = cv2.VideoCapture(0)  # Use 0 for default camera

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        break

    # Analyze frame for age and gender
    try:
        results = DeepFace.analyze(frame, actions=['age', 'gender'], enforce_detection=False)
        for result in results:
            age = result.get('age')
            gender = result.get('dominant_gender')

            # Display results on frame
            cv2.putText(frame, f"Age: {age}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Gender: {gender}", (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    except ValueError:
        # Handle cases where no face is detected
        cv2.putText(frame, "No face detected", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Display the resulting frame
    cv2.imshow('Live Age and Gender Prediction', frame)

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

# Load pre-trained models
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
age_model = load_model('age_model.h5')
gender_model = load_model('gender_model.h5')

# Define age and gender labels
age_labels = ['0-2', '4-6', '8-12', '15-20', '25-32', '38-43', '48-53', '60+']
gender_labels = ['Male', 'Female']

# Initialize video capture
cap = cv2.VideoCapture(0)

while True:
    # Read frame from camera
    ret, frame = cap.read()
    if not ret:
        break

    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract face ROI
        face_roi = frame[y:y+h, x:x+w]

        # Preprocess for age and gender models
        face_roi = cv2.resize(face_roi, (200, 200))
        face_roi = face_roi.astype("float") / 255.0
        face_roi = img_to_array(face_roi)
        face_roi = np.expand_dims(face_roi, axis=0)

        # Predict age
        age_preds = age_model.predict(face_roi)
        age = age_labels[age_preds[0].argmax()]

        # Predict gender
        gender_preds = gender_model.predict(face_roi)
        gender = gender_labels[gender_preds[0].argmax()]

        # Draw rectangle around face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # Display predictions
        label = f"{gender}, {age}"
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow('Age and Gender Prediction', frame)

    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-b2860ce72939> in <cell line: 8>()
#       6 # Load pre-trained models
#       7 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# ----> 8 age_model = load_model('age_model.h5')
#       9 gender_model = load_model('gender_model.h5')
#      10
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
# ...

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

# Load pre-trained models
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Update paths to your actual model files if they are in a different directory
age_model_path = 'path/to/your/age_model.h5'  # Replace with the correct path
gender_model_path = 'path/to/your/gender_model.h5'  # Replace with the correct path

age_model = load_model(age_model_path)
gender_model = load_model(gender_model_path)

# Define age and gender labels
age_labels = ['0-2', '4-6', '8-12', '15-20', '25-32', '38-43', '48-53', '60+']
gender_labels = ['Male', 'Female']

# Initialize video capture
cap = cv2.VideoCapture(0)

# ... (rest of your code)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-29-c9529479a5a1> in <cell line: 13>()
#      11 gender_model_path = 'path/to/your/gender_model.h5'  # Replace with the correct path
#      12
# ---> 13 age_model = load_model(age_model_path)
#      14 gender_model = load_model(gender_model_path)
#      15
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
# ...

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

# Load pre-trained models
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
age_model = load_model('age_model.h5')
gender_model = load_model('gender_model.h5')

# Define age and gender labels
age_labels = ['0-2', '4-6', '8-12', '15-20', '25-32', '38-43', '48-53', '60+']
gender_labels = ['Male', 'Female']

# Initialize video capture
cap = cv2.VideoCapture(0)

while True:
    # Read frame from camera
    ret, frame = cap.read()
    if not ret:
        break

    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract face ROI
        face_roi = frame[y:y+h, x:x+w]

        # Preprocess for age and gender models
        face_roi = cv2.resize(face_roi, (200, 200))
        face_roi = face_roi.astype("float") / 255.0
        face_roi = img_to_array(face_roi)
        face_roi = np.expand_dims(face_roi, axis=0)

        # Predict age
        age_preds = age_model.predict(face_roi)
        age = age_labels[age_preds[0].argmax()]

        # Predict gender
        gender_preds = gender_model.predict(face_roi)
        gender = gender_labels[gender_preds[0].argmax()]

        # Draw rectangle around face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # Display predictions
        label = f"{gender}, {age}"
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow('Age and Gender Prediction', frame)

    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-b2860ce72939> in <cell line: 8>()
#       6 # Load pre-trained models
#       7 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# ----> 8 age_model = load_model('age_model.h5')
#       9 gender_model = load_model('gender_model.h5')
#      10
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
# ...

# %%
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow
import gdown

# Install required packages
# !pip install opencv-python-headless

# Download pre-trained models
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# !wget https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !gdown --id 1W_moLzMlGiELyPxWiYQJ9KFaXroQ_NFQ

# Load pre-trained models
face_proto = "deploy.prototxt"
face_model = "res10_300x300_ssd_iter_140000.caffemodel"
gender_proto = "gender_deploy.prototxt"
gender_model = "gender_net.caffemodel"

# Load network
face_net = cv2.dnn.readNet(face_model, face_proto)
gender_net = cv2.dnn.readNet(gender_model, gender_proto)

# Model parameters
mean_values = (78.4263377603, 87.7689143744, 114.895847746)
gender_list = ['Male', 'Female']

# Helper functions
def get_face_box(net, frame, conf_threshold=0.7):
    frame_opencv_dnn = frame.copy()
    frame_height = frame_opencv_dnn.shape[0]
    frame_width = frame_opencv_dnn.shape[1]
    blob = cv2.dnn.blobFromImage(frame_opencv_dnn, 1.0, (300, 300), [104, 117, 123], True, False)

    net.setInput(blob)
    detections = net.forward()
    face_boxes = []
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > conf_threshold:
            x1 = int(detections[0, 0, i, 3] * frame_width)
            y1 = int(detections[0, 0, i, 4] * frame_height)
            x2 = int(detections[0, 0, i, 5] * frame_width)
            y2 = int(detections[0, 0, i, 6] * frame_height)
            face_boxes.append([x1, y1, x2, y2])
    return face_boxes

def predict_gender(input_path):
    frame = cv2.imread(input_path)
    face_boxes = get_face_box(face_net, frame)
    for face_box in face_boxes:
        face = frame[max(0, face_box[1]):min(face_box[3], frame.shape[0] - 1),
                     max(0, face_box[0]):min(face_box[2], frame.shape[1] - 1)]

        blob = cv2.dnn.blobFromImage(face, 1.0, (227, 227), mean_values, swapRB=False)
        gender_net.setInput(blob)
        gender_preds = gender_net.forward()
        gender = gender_list[gender_preds[0].argmax()]

        label = f"Gender: {gender}"
        cv2.putText(frame, label, (face_box[0], face_box[1] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2, cv2.LINE_AA)
        cv2.rectangle(frame, (face_box[0], face_box[1]), (face_box[2], face_box[3]), (0, 255, 0), 2)

    return frame

# Main execution
print("Upload an image file for gender prediction")
uploaded = files.upload()
image_file = next(iter(uploaded))

# Process the image and predict gender
result_image = predict_gender(image_file)

# Display the result
print("Result:")
cv2_imshow(result_image)

# Save and download the result
output_file = 'gender_prediction_' + image_file
cv2.imwrite(output_file, result_image)
files.download(output_file)

print("Gender prediction complete!")
# Out:
# ...
# --2024-08-10 14:29:52--  https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28104 (27K) [text/plain]
# Saving to: ‘deploy.prototxt’
#
# deploy.prototxt     100%[===================>]  27.45K  --.-KB/s    in 0.002s
#
# 2024-08-10 14:29:52 (17.3 MB/s) - ‘deploy.prototxt’ saved [28104/28104]
#
# --2024-08-10 14:29:53--  https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow
import gdown

# Install required packages
# !pip install opencv-python-headless

# Download pre-trained models
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# !wget https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !gdown --id 1W_moLzMlGiELyPxWiYQJ9KFaXroQ_NFQ

# Load pre-trained models
face_proto = "deploy.prototxt"
face_model = "res10_300x300_ssd_iter_140000.caffemodel"
gender_proto = "gender_deploy.prototxt"  # Make sure this file exists in the current directory
gender_model = "gender_net.caffemodel"  # Make sure this file exists in the current directory

# Load network
face_net = cv2.dnn.readNet(face_model, face_proto)
gender_net = cv2.dnn.readNet(gender_model, gender_proto)

# ... (rest of the code remains the same)
# Out:
# ...
# --2024-08-10 14:30:54--  https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28104 (27K) [text/plain]
# Saving to: ‘deploy.prototxt.1’
#
# deploy.prototxt.1   100%[===================>]  27.45K  --.-KB/s    in 0.002s
#
# 2024-08-10 14:30:54 (16.6 MB/s) - ‘deploy.prototxt.1’ saved [28104/28104]
#
# --2024-08-10 14:30:54--  https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from IPython.display import display, Javascript, HTML
from google.colab import output
import base64
import time

# Install required packages
# !pip install opencv-python-headless
# !pip install dlib

# Download pre-trained models
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# !wget https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !wget https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/age_net.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/gender_net.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/age_deploy.prototxt
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/gender_deploy.prototxt

# Load pre-trained models
face_proto = "deploy.prototxt"
face_model = "res10_300x300_ssd_iter_140000.caffemodel"
age_proto = "age_deploy.prototxt"
age_model = "age_net.caffemodel"
gender_proto = "gender_deploy.prototxt"
gender_model = "gender_net.caffemodel"

# Load network
face_net = cv2.dnn.readNet(face_model, face_proto)
age_net = cv2.dnn.readNet(age_model, age_proto)
gender_net = cv2.dnn.readNet(gender_model, gender_proto)

# Model parameters
mean_values = (78.4263377603, 87.7689143744, 114.895847746)
age_list = ['(0-2)', '(4-6)', '(8-12)', '(15-20)', '(25-32)', '(38-43)', '(48-53)', '(60-100)']
gender_list = ['Male', 'Female']

def get_face_box(net, frame, conf_threshold=0.7):
    frame_opencv_dnn = frame.copy()
    frame_height = frame_opencv_dnn.shape[0]
    frame_width = frame_opencv_dnn.shape[1]
    blob = cv2.dnn.blobFromImage(frame_opencv_dnn, 1.0, (300, 300), [104, 117, 123], True, False)

    net.setInput(blob)
    detections = net.forward()
    face_boxes = []
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > conf_threshold:
            x1 = int(detections[0, 0, i, 3] * frame_width)
            y1 = int(detections[0, 0, i, 4] * frame_height)
            x2 = int(detections[0, 0, i, 5] * frame_width)
            y2 = int(detections[0, 0, i, 6] * frame_height)
            face_boxes.append([x1, y1, x2, y2])
    return face_boxes

def predict_age_gender(frame):
    face_boxes = get_face_box(face_net, frame)
    for face_box in face_boxes:
        face = frame[max(0, face_box[1]):min(face_box[3], frame.shape[0] - 1),
                     max(0, face_box[0]):min(face_box[2], frame.shape[1] - 1)]

        blob = cv2.dnn.blobFromImage(face, 1.0, (227, 227), mean_values, swapRB=False)

        gender_net.setInput(blob)
        gender_preds = gender_net.forward()
        gender = gender_list[gender_preds[0].argmax()]

        age_net.setInput(blob)
        age_preds = age_net.forward()
        age = age_list[age_preds[0].argmax()]

        label = f"{gender}, {age}"
        cv2.putText(frame, label, (face_box[0], face_box[1] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2, cv2.LINE_AA)
        cv2.rectangle(frame, (face_box[0], face_box[1]), (face_box[2], face_box[3]), (0, 255, 0), 2)

    return frame

def js_to_image(js_reply):
    image_bytes = base64.b64decode(js_reply.split(',')[1])
    jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
    img = cv2.imdecode(jpg_as_np, flags=1)
    return img

def video_stream():
    js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;

    var pendingResolve = null;
    var shutdown = false;

    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }

    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }

    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);

      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);

      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);

      const instruction = document.createElement('div');
      instruction.innerHTML =
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };

      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);

      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();

      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }

      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }

      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;

      return {'create': preShow - preCreate,
              'show': preCapture - preShow,
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

    display(js)

    def video_frame(label, bbox):
        data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
        return data

    # start streaming
    label = "Predicted Age and Gender"
    bbox = ''
    result = video_frame(label, bbox)

    return result

def process_frame(frame):
    # Convert the frame from BGR to RGB color space
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Perform age and gender prediction
    processed_frame = predict_age_gender(frame_rgb)

    # Convert the processed frame back to BGR color space
    processed_frame_bgr = cv2.cvtColor(processed_frame, cv2.COLOR_RGB2BGR)

    return processed_frame_bgr

# Main execution
print("Starting live camera feed. Click on the video to stop.")

while True:
    frame = video_stream()
    if frame['img'] == '':
        break

    img = js_to_image(frame['img'])

    processed_frame = process_frame(img)

    cv2_imshow(processed_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    time.sleep(0.1)  # Add a small delay to reduce processing load

print("Camera feed ended.")
# Out:
# ...
# --2024-08-10 14:32:14--  https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28104 (27K) [text/plain]
# Saving to: ‘deploy.prototxt.2’
#
# deploy.prototxt.2   100%[===================>]  27.45K  --.-KB/s    in 0.002s
#
# 2024-08-10 14:32:14 (11.8 MB/s) - ‘deploy.prototxt.2’ saved [28104/28104]
#
# --2024-08-10 14:32:14--  https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# Download pre-trained models
# !wget -O deploy.prototxt https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# !wget -O res10_300x300_ssd_iter_140000.caffemodel https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !wget -O age_deploy.prototxt https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/age_deploy.prototxt
# !wget -O age_net.caffemodel https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/age_net.caffemodel
# !wget -O gender_deploy.prototxt https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/gender_deploy.prototxt
# !wget -O gender_net.caffemodel https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/gender_net.caffemodel
# Out:
# --2024-08-10 14:34:49--  https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28104 (27K) [text/plain]
# Saving to: ‘deploy.prototxt’
#
# deploy.prototxt     100%[===================>]  27.45K  --.-KB/s    in 0.002s
#
# 2024-08-10 14:34:49 (17.6 MB/s) - ‘deploy.prototxt’ saved [28104/28104]
#
# --2024-08-10 14:34:49--  https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from IPython.display import display, Javascript, HTML
from google.colab import output
import base64
import time

# Install required packages
# !pip install opencv-python-headless
# !pip install dlib

# Download pre-trained models
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# !wget https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !wget https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/age_net.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/gender_net.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/age_deploy.prototxt
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/gender_deploy.prototxt

# Load pre-trained models
face_proto = "deploy.prototxt"
face_model = "res10_300x300_ssd_iter_140000.caffemodel"
age_proto = "age_deploy.prototxt"  # Verify that this file is present in the current directory
age_model = "age_net.caffemodel"  # Verify that this file is present in the current directory
gender_proto = "gender_deploy.prototxt"
gender_model = "gender_net.caffemodel"

# Load network
face_net = cv2.dnn.readNet(face_model, face_proto)

# Check if the age_deploy.prototxt file exists
import os
if not os.path.exists(age_proto):
    print(f"Error: {age_proto} not found. Please download it.")
else:
    age_net = cv2.dnn.readNet(age_model, age_proto)  # Load only if the file exists

gender_net = cv2.dnn.readNet(gender_model, gender_proto)

# ... (rest of the code remains the same)
# Out:
# ...
# --2024-08-10 14:35:15--  https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28104 (27K) [text/plain]
# Saving to: ‘deploy.prototxt.3’
#
# deploy.prototxt.3   100%[===================>]  27.45K  --.-KB/s    in 0.002s
#
# 2024-08-10 14:35:16 (17.1 MB/s) - ‘deploy.prototxt.3’ saved [28104/28104]
#
# --2024-08-10 14:35:16--  https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# Install gdown to download files from Google Drive
# !pip install gdown

# Download pre-trained models
# !wget -O deploy.prototxt https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# !wget -O res10_300x300_ssd_iter_140000.caffemodel https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel

# Download age and gender models from Google Drive
# !gdown --id 1_aDScOvBeBLCn_iv0oxSO6d1Eu_Sswob -O age_gender_models.zip
# !unzip age_gender_models.zip
# !mv age_deploy.prototxt gender_deploy.prototxt age_net.caffemodel gender_net.caffemodel ./
# !rm age_gender_models.zip
# Out:
# ...
# --2024-08-10 14:38:09--  https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28104 (27K) [text/plain]
# Saving to: ‘deploy.prototxt’
#
# deploy.prototxt     100%[===================>]  27.45K  --.-KB/s    in 0.002s
#
# 2024-08-10 14:38:09 (15.3 MB/s) - ‘deploy.prototxt’ saved [28104/28104]
#
# --2024-08-10 14:38:09--  https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Load pre-trained models
face_proto = "deploy.prototxt"
face_model = "res10_300x300_ssd_iter_140000.caffemodel"
age_proto = "age_deploy.prototxt"
age_model = "age_net.caffemodel"
gender_proto = "gender_deploy.prototxt"
gender_model = "gender_net.caffemodel"

# Load network
face_net = cv2.dnn.readNet(face_model, face_proto)
age_net = cv2.dnn.readNet(age_model, age_proto)
gender_net = cv2.dnn.readNet(gender_model, gender_proto)

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from IPython.display import display, Javascript, HTML
from google.colab import output
import base64
import time

# Install required packages
# !pip install opencv-python-headless
# !pip install dlib

# Download pre-trained models
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# !wget https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !wget https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/age_net.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/gender_net.caffemodel
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/age_deploy.prototxt
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/age_gender_models/gender_deploy.prototxt

# Load pre-trained models
face_proto = "deploy.prototxt"
face_model = "res10_300x300_ssd_iter_140000.caffemodel"
age_proto = "age_deploy.prototxt"  # Verify that this file is present in the current directory
age_model = "age_net.caffemodel"  # Verify that this file is present in the current directory
gender_proto = "gender_deploy.prototxt"
gender_model = "gender_net.caffemodel"

# Load network
face_net = cv2.dnn.readNet(face_model, face_proto)

# Check if the age_deploy.prototxt file exists
import os
if not os.path.exists(age_proto):
    print(f"Error: {age_proto} not found. Please download it.")
else:
    age_net = cv2.dnn.readNet(age_model, age_proto)  # Load only if the file exists

gender_net = cv2.dnn.readNet(gender_model, gender_proto)

# ... (rest of the code remains the same)
# Out:
# ...
# --2024-08-10 14:39:15--  https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28104 (27K) [text/plain]
# Saving to: ‘deploy.prototxt.4’
#
# deploy.prototxt.4   100%[===================>]  27.45K  --.-KB/s    in 0.002s
#
# 2024-08-10 14:39:15 (16.4 MB/s) - ‘deploy.prototxt.4’ saved [28104/28104]
#
# --2024-08-10 14:39:15--  https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# ...
