# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishjhavats/Colab_demo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
plt.plot([1, 2, 3, 4], [5, 6, 7, 8])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sample Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-80a3c6335e9e> in <cell line: 1>()
# ----> 1 plt.plot([1, 2, 3, 4], [5, 6, 7, 8])
#       2 plt.xlabel("X-axis")
#       3 plt.ylabel("Y-axis")
#       4 plt.title("Sample Plot")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt # Import the matplotlib.pyplot module and alias it as plt

plt.plot([1, 2, 3, 4], [5, 6, 7, 8])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sample Plot")
plt.show()

# %%
importimport matplotlib.pyplot as plt
